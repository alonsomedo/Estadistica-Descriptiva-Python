# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4]

# %%
print('En python a diferencia de R, no se pintan los puntos sino que estos se unen')
print('Cuando solo damos una lista de valores, estas se consideran en el eje de ordenadas')
plt.plot(x)
plt.xlabel("Eje de abcisas")
plt.ylabel("Eje de ordenadas")
plt.show()
# Out:
# En python a diferencia de R, no se pintan los puntos sino que estos se unen
# Cuando solo damos una lista de valores, estas se consideran en el eje de ordenadas

# %%
x = [1,2,3,4]
y = np.power(x,2).tolist()

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"ro")
plt.axis([0,6,0,20])
plt.show()

# %%
data = np.arange(0.0, 10.0, 0.2)
data
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. ,
#        5.2, 5.4, 5.6, 5.8, 6. , 6.2, 6.4, 6.6, 6.8, 7. , 7.2, 7.4, 7.6,
#        7.8, 8. , 8.2, 8.4, 8.6, 8.8, 9. , 9.2, 9.4, 9.6, 9.8])

# %%
plt.plot(data, data, "r--", data, data**2, "bs", data, data**3, "g*")
plt.show()

# %%
plt.plot(x,y, linewidth =3)
plt.show()

# %%
line, = plt.plot(x,y,'-')
line.set_antialiased(False)

# %%
lines = plt.plot(data, data, data, data**2)
plt.setp(lines, color = "r", linewidth= 2.0)
# Out:
# [None, None, None, None]

# %%
lines = plt.plot(data, data, data, data**2)
plt.setp(lines, "color", "r", "linewidth", 2.0)
plt.show()

# %%
plt.plot(x,y, marker = "+", linestyle = ":")

# %% [markdown]
# # Multiples Graficos en Figuras

# %%
def f(x):
    return np.exp(-x)*np.cos(2*np.pi*x)

# %%
x1 = np.arange(0,5,0.1)
x2 = np.arange(0,5.0,0.2)

# %%
plt.figure(1) #este parametro es adicional
plt.subplot(211) #el doble de ancho que de alto y primer grafico, 2 filas y una columna
plt.plot(x1,f(x1), 'ro', x2, f(x2), 'k')

plt.subplot(212) #el doble de ancho que de alto y segundo grafico
plt.plot(x2, f(x2), 'g--')

plt.show()

# %%
plt.figure(1)
plt.subplot(211)
plt.plot([1,2,3])

plt.subplot(212)
plt.plot([4,5,6])

plt.figure(2)
plt.plot([4,5,6])

plt.figure(1)
plt.subplot(211)
plt.title("Este es el primer titulo")
# Out:
# D:\Archivos de Programa\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':
# Text(0.5, 1.0, 'Este es el primer titulo')

# %% [markdown]
# # Texto en los gráficos

# %%
mu = 100
sigma = 20
x = mu + sigma * np.random.randn(10000)

# %%
n, bins, patches = plt.hist(x, 50, normed=1, facecolor = "g", alpha=0.6)

plt.xlabel("Cociente Intelectual")
plt.ylabel("Probabilidad")
plt.title("Histograma de CI")
plt.text(20,0.015,r'$\mu = 100, \ \sigma=20$')
plt.grid(True,alpha=0.2)
plt.axis([20,180,0,0.025])
plt.show()
# Out:
# D:\Archivos de Programa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.subplot(111)

x = np.arange(0, 10*np.pi, 0.01)
y = np.cos(x)
plt.plot(x,y,linewidth=2.0)

plt.annotate('Maximo Local', xy= (4*np.pi,1), xytext = (15,1.5),
            arrowprops = dict(facecolor = 'black', shrink = 0.05))

plt.ylim(-2,2)
plt.show()

# %%
mu = 0.5
sd = 0.3

y = mu + sd*np.random.randn(1000)
y = y[(y>0) & (y<1)]
y.sort()

x = np.arange(len(y))

# %%
plt.figure(figsize = (10,6))
plt.subplot(221)
plt.plot(x,y)
plt.yscale("linear")
plt.xscale("linear")
plt.title("Escala Lineal")
plt.grid(True, alpha=0.4)

plt.subplot(222)
plt.plot(x,y)
plt.yscale("log")
plt.title("Escala Logaritmica")
plt.grid(True, alpha=0.4)

plt.subplot(223)
plt.plot(x,y - y.mean())
plt.yscale("symlog", linthreshy=0.01)
plt.title("Escala Log Simetrico")
plt.grid(True, alpha=0.4)

plt.subplot(224)
plt.plot(x,y)
plt.yscale("logit")
plt.title("Escala Logistica")
plt.grid(True, alpha=0.4)

plt.subplots_adjust(top = 0.92, bottom = 0.08, left = 0.1, right = 0.95, hspace = 0.5, wspace = 0.5)
plt.show()

# %% [markdown]
# # Cambios en los ejes

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
S,C = np.sin(x), np.cos(x)

# %%
plt.plot(x, S, color="blue", linewidth = 1.2, linestyle = "-")
plt.plot(x,C, color="green", linewidth = 1.2, linestyle = "-")
plt.xlim(x.min()*1.1, x.max()*1.1)
plt.ylim(S.min()*1.1, S.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks(np.linspace(-1, 1, 9, endpoint = True))
plt.show()
